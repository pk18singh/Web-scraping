# %%
with open('smartprix.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
soup = BeautifulSoup(html,'lxml')

# %%
containers = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(names)
# Out:
# 1020

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df.head()
# Out:
#                   model    price rating  \
# 0  Motorola Edge 40 Neo  ₹22,999     84
# 1  OnePlus Nord CE 3 5G  ₹24,999     84
# 2    Xiaomi Redmi 12 5G  ₹11,999     75
# 3              Vivo V29  ₹31,300     85
# 4  Motorola Moto G54 5G  ₹13,999     84
#
#                                                  sim  \
# 0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 4                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                       ram  \
# 0     Dimensity 7030, Octa Core, 2.5 GHz Processor  8 GB RAM, 128 GB inbuilt
# 1   Snapdragon  782G, Octa Core, 2.7 GHz Processor  8 GB RAM, 128 GB inbuilt
# 2  Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor  4 GB RAM, 128 GB inbuilt
# 3    Snapdragon 778G, Octa Core, 2.4 GHz Processor  8 GB RAM, 128 GB inbuilt
# 4     Dimensity 7020, Octa Core, 2.2 GHz Processor  8 GB RAM, 128 GB inbuilt
#
#                                    battery  \
# 0  5000 mAh Battery with 68W Fast Charging
# 1  5000 mAh Battery with 80W Fast Charging
# 2  5000 mAh Battery with 18W Fast Charging
# 3  4600 mAh Battery with 80W Fast Charging
# 4  6000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.55 inches, 1080 x 2400 px, 144 Hz Display wi...
# 1  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 2  6.79 inches, 1080 x 2460 px, 90 Hz Display wit...
# 3  6.78 inches, 1260 x 2800 px, 120 Hz Display wi...
# 4  6.5 inches, 1080 x 2400 px, 120 Hz Display wit...
#
#                                               camera  \
# 0       50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 1  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 2         50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 3  50 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# 4        50 MP + 8 MP Dual Rear & 16 MP Front Camera
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v13
# 2  Memory Card (Hybrid), upto 1 TB  Android v13
# 3                      Android v13  No FM Radio
# 4  Memory Card (Hybrid), upto 1 TB  Android v13
